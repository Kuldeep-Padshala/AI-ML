# %%
import pandas as pd
import requests   # type: ignore

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#    'genre_ids': [12, 16, 10751, 14],
#    'id': 1007757,
#    'title': 'Swapped',
#    'original_language': 'en',
#    'original_title': 'Swapped',
#    'overview': 'A small woodland creature and a majestic bird, two natural sworn enemies of the Valley, magically trade places and set off on an adventure of a lifetime to switch back. Their journey soon uncovers a greater threat—one that could endanger not only their species, but the entire valley they call home.',
#    'popularity': 248.6425,
#    'poster_path': '/tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg',
#    'release_date': '2026-05-01',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.976,
#    'vote_count': 1525},
#   {'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'title': 'The Shawshank Redemption',
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 80.3109,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.722,
#    'vote_count': 30462},
#   {'adult': False,
#    'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'title': 'The Godfather',
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 45.1275,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.687,
#    'vote_count': 22978},
#   {'adult': False,
#    'backdrop_path': '/2I1OFQJ0L9T0dpU6FobKFWV2PxX.jpg',
#    'genre_ids': [878, 12],
#    'id': 687163,
#    'title': 'Project Hail Mary',
#    'original_language': 'en',
#    'original_title': 'Project Hail Mary',
#    'overview': 'Science teacher Ryland Grace wakes up on a spaceship light years from home with no recollection of who he is or how he got there. As his memory returns, he begins to uncover his mission: solve the riddle of the mysterious substance causing the sun to die out. He must call on his scientific knowledge and unorthodox ideas to save everything on Earth from extinction.',
#    'popularity': 282.2181,
#    'poster_path': '/yihdXomYb5kTeSivtFndMy5iDmf.jpg',
#    'release_date': '2026-03-15',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.645,
#    'vote_count': 4525},
#   {'adult': False,
#    'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#    'genre_ids': [18, 80],
#    'id': 240,
#    'title': 'The Godfather Part II',
#    'original_language': 'en',
#    'original_title': 'The Godfather Part II',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'popularity': 28.7212,
#    'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#    'release_date': '1974-12-20',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 13930},
#   {'adult': False,
#    'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#    'genre_ids': [18, 36, 10752],
#    'id': 424,
#    'title': "Schindler's List",
#    'original_language': 'en',
#    'original_title': "Schindler's List",
#    'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#    'popularity': 26.4605,
#    'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#    'release_date': '1993-12-15',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.569,
#    'vote_count': 17474},
#   {'adult': False,
#    'backdrop_path': '/w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg',
#    'genre_ids': [18],
#    'id': 389,
#    'title': '12 Angry Men',
#    'original_language': 'en',
#    'original_title': '12 Angry Men',
#    'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#    'popularity': 24.7146,
#    'poster_path': '/zhG3vKWyDRaZYoaww1UVAi29T9h.jpg',
#    'release_date': '1957-04-10',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.561,
#    'vote_count': 10002},
#   {'adult': False,
#    'backdrop_path': '/bVGHSe47W6oCQL1Q88pvRAet51A.jpg',
#    'genre_ids': [18, 9648],
#    'id': 1330021,
#    'title': 'Remarkably Bright Creatures',
#    'original_language': 'en',
#    'original_title': 'Remarkably Bright Creatures',
#    'overview': 'Through unlikely bonds formed during night shifts at a local aquarium, Tova, an elderly widow, learns of a life-changing discovery that may bring her joy and wonder once again.',
#    'popularity': 65.5422,
#    'poster_path': '/9HcEqn3D4J6b2Z0jK54id9nA0fr.jpg',
#    'release_date': '2026-05-07',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.547,
#    'vote_count': 519},
#   {'adult': False,
#    'backdrop_path': '/dyJvKsNs2KP8qQnAXbRwDjblViy.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 129,
#    'title': 'Spirited Away',
#    'original_language': 'ja',
#    'original_title': '千と千尋の神隠し',
#    'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#    'popularity': 37.3901,
#    'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#    'release_date': '2001-07-20',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.535,
#    'vote_count': 18342},
#   {'adult': False,
#    'backdrop_path': '/cfT29Im5VDvjE0RpyKOSdCKZal7.jpg',
#    'genre_ids': [28, 80, 53],
#    'id': 155,
#    'title': 'The Dark Knight',
#    'original_language': 'en',
#    'original_title': 'The Dark Knight',
#    'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#    'popularity': 44.7903,
#    'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#    'release_date': '2008-07-16',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.531,
#    'vote_count': 35823},
#   {'adult': False,
#    'backdrop_path': '/84beTJf26mfhoasUlKSOiNSutyS.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 19.0525,
#    'poster_path': '/tFbfCkS7q6g96wVoAu8kyr93iPm.jpg',
#    'release_date': '1995-10-20',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.513,
#    'vote_count': 4591},
#   {'adult': False,
#    'backdrop_path': '/b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg',
#    'genre_ids': [14, 18, 80],
#    'id': 497,
#    'title': 'The Green Mile',
#    'original_language': 'en',
#    'original_title': 'The Green Mile',
#    'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#    'popularity': 28.4985,
#    'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#    'release_date': '1999-12-10',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.507,
#    'vote_count': 19279},
#   {'adult': False,
#    'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 122,
#    'title': 'The Lord of the Rings: The Return of the King',
#    'original_language': 'en',
#    'original_title': 'The Lord of the Rings: The Return of the King',
#    'overview': 'As armies mass for a final battle that will decide the fate of the world--and powerful, ancient forces of Light and Dark compete to determine the outcome--one member of the Fellowship of the Ring is revealed as the noble heir to the throne of the Kings of Men. Yet, the sole hope for triumph over evil lies with a brave hobbit, Frodo, who, accompanied by his loyal friend Sam and the hideous, wretched Gollum, ventures deep into the very dark heart of Mordor on his seemingly impossible quest to destroy the Ring of Power.\u200b',
#    'popularity': 42.0542,
#    'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#    'release_date': '2003-12-17',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.499,
#    'vote_count': 26578},
#   {'adult': False,
#    'backdrop_path': '/TU9NIjwzjoKPwQHoHshkFcQUCG.jpg',
#    'genre_ids': [35, 53, 18],
#    'id': 496243,
#    'title': 'Parasite',
#    'original_language': 'ko',
#    'original_title': '기생충',
#    'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#    'popularity': 37.715,
#    'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#    'release_date': '2019-05-30',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.495,
#    'vote_count': 20662},
#   {'adult': False,
#    'backdrop_path': '/xyWKrni8WrYzqn7ztvI5nIY0h62.jpg',
#    'genre_ids': [35, 10749],
#    'id': 1181678,
#    'title': '¿Quieres ser mi hijo?',
#    'original_language': 'en',
#    'original_title': '¿Quieres ser mi hijo?',
#    'overview': 'Lu, a conformist woman in her forties, learns that her 15-year partner has been having extramarital affairs. Starting from scratch, she gets involved in an unexpected relationship with a young womanizer.',
#    'popularity': 12.9091,
#    'poster_path': '/6PQJsmuvSMZQMmlJfTpjIkrizUh.jpg',
#    'release_date': '2023-09-21',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.489,
#    'vote_count': 353},
#   {'adult': False,
#    'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#    'genre_ids': [53, 80, 35],
#    'id': 680,
#    'title': 'Pulp Fiction',
#    'original_language': 'en',
#    'original_title': 'Pulp Fiction',
#    'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#    'popularity': 38.737,
#    'poster_path': '/vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg',
#    'release_date': '1994-09-10',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.484,
#    'vote_count': 30227},
#   {'adult': False,
#    'backdrop_path': '/8x9iKH8kWA0zdkgNdpAew7OstYe.jpg',
#    'genre_ids': [16, 10749, 18],
#    'id': 372058,
#    'title': 'Your Name.',
#    'original_language': 'ja',
#    'original_title': '君の名は。',
#    'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    'popularity': 31.7055,
#    'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#    'release_date': '2016-08-26',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.48,
#    'vote_count': 12579},
#   {'adult': False,
#    'backdrop_path': '/2ssWTSVklAEc98frZUQhgtGHx7s.jpg',
#    'genre_ids': [12, 18, 878],
#    'id': 157336,
#    'title': 'Interstellar',
#    'original_language': 'en',
#    'original_title': 'Interstellar',
#    'overview': 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#    'popularity': 74.4364,
#    'poster_path': '/yQvGrMoipbRoddT0ZR8tPoR7NfX.jpg',
#    'release_date': '2014-11-05',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.476,
#    'vote_count': 39889},
#   {'adult': False,
#    'backdrop_path': '/Adrip2Jqzw56KeuV2nAxucKMNXA.jpg',
#    'genre_ids': [37],
#    'id': 429,
#    'title': 'The Good, the Bad and the Ugly',
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'popularity': 22.6911,
#    'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#    'release_date': '1966-12-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.468,
#    'vote_count': 9655},
#   {'adult': False,
#    'backdrop_path': '/66Kn4XWhkuPkJxOJyPEx4U2CUfN.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 13,
#    'title': 'Forrest Gump',
#    'original_language': 'en',
#    'original_title': 'Forrest Gump',
#    'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#    'popularity': 28.7475,
#    'poster_path': '/Cw4hIUIAmSYfK9QfaUW5igp9La.jpg',
#    'release_date': '1994-06-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 8.465,
#    'vote_count': 29772}],
#  'total_pages': 545,
#  'total_results': 10895}

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
#
#                       title original_language            original_title  \
# 0                   Swapped                en                   Swapped
# 1  The Shawshank Redemption                en  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  A small woodland creature and a majestic bird,...    248.6425
# 1  Imprisoned in the 1940s for the double murder ...     80.3109
#
#                         poster_path release_date  softcore  video  \
# 0  /tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg   2026-05-01     False  False
# 1  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23     False  False
#
#    vote_average  vote_count
# 0         8.976        1525
# 1         8.722       30462

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
# 2      238             The Godfather
# 3   687163         Project Hail Mary
# 4      240     The Godfather Part II
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    248.6425
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23     80.3109
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     45.1275
# 3  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    282.2181
# 4  In the continuing saga of the Corleone crime f...   1974-12-20     28.7212
#
#    vote_average  vote_count
# 0         8.976        1525
# 1         8.722       30462
# 2         8.687       22978
# 3         8.645        4525
# 4         8.600       13930

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    # df = df.append(temp_df,ignore_index=True)
    # df.append() is deprecated in pandas 2.0, so we can use pd.concat() instead
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#            id                     title  \
# 0     1007757                   Swapped
# 1         278  The Shawshank Redemption
# 2         238             The Godfather
# 3      687163         Project Hail Mary
# 4         240     The Godfather Part II
# ...       ...                       ...
# 8555    10547               The Arrival
# 8556    10066              House of Wax
# 8557    11834               Jabberwocky
# 8558   872709   Smoking Causes Coughing
# 8559   819876      Crimes of the Future
#
#                                                overview release_date  \
# 0     A small woodland creature and a majestic bird,...   2026-05-01
# 1     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3     Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 4     In the continuing saga of the Corleone crime f...   1974-12-20
# ...                                                 ...          ...
# 8555  Zane Ziminski is an astrophysicist who receive...   1996-05-31
# 8556  A group of unwitting teens are stranded near a...   2005-05-05
# 8557  After the death of his father, young Dennis Co...   1977-03-28
# 8558  After a devastating battle against a diabolica...   2022-11-30
# 8559  With his partner Caprice, celebrity performanc...   2022-05-25
#
#       popularity  vote_average  vote_count
# 0       248.6425         8.976        1525
# 1        80.3109         8.722       30462
# 2        45.1275         8.687       22978
# 3       282.2181         8.645        4525
# 4        28.7212         8.600       13930
# ...          ...           ...         ...
# 8555      3.4844         6.028         835
# 8556      5.4062         6.029        3343
# 8557      1.4277         6.027         316
# 8558      0.6978         6.026         408
# 8559      2.8263         6.000        1276
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
